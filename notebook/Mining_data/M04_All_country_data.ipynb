# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ADMIN\Downloads\MODEL_TFT\data\raw\ember_data\all_country_data2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12227 entries, 0 to 12226
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Area                 12227 non-null  object
#  1   ISO 3 code           12227 non-null  object
#  2   Date                 12227 non-null  object
#  3   Area type            12227 non-null  object
#  4   Continent            12227 non-null  object
#  5   Ember region         12227 non-null  object
#  6   EU                   12227 non-null  int64
#  7   OECD                 12227 non-null  int64
#  8   G20                  12227 non-null  int64
#  9   G7                   12227 non-null  int64
#  10  ASEAN                12227 non-null  int64
#  11  Category             12227 non-null  object
#  12  Subcategory          12227 non-null  object
#  13  Variable             12227 non-null  object
#  14  Unit                 12227 non-null  object
# ...

# %% [markdown]
# 0,1,2,13,15

# %%
# filter data
data = df.drop(columns=[ 'Area type', 'Continent', 'Ember region', 'EU', 'OECD', 'G20', 'G7', 'ASEAN','Category', 'Subcategory', 'Unit','YoY absolute change', 'YoY % change'])
data.head()
# Out:
#         Area ISO 3 code        Date   Variable  Value
# 0  Argentina        ARG  01/01/2018  Bioenergy   0.02
# 1  Argentina        ARG  01/01/2018       Coal   0.26
# 2  Argentina        ARG  01/01/2018        Gas   7.79
# 3  Argentina        ARG  01/01/2018      Hydro   3.69
# 4  Argentina        ARG  01/01/2018    Nuclear   0.64

# %%
# Đổi tên lần lượt các cột thành : entity, entity_code, date, series, generation_twh
data.columns = ['entity', 'entity code', 'date', 'series', 'generation_TWh']
data.head()
# Out:
#       entity entity code        date     series  generation_TWh
# 0  Argentina         ARG  01/01/2018  Bioenergy            0.02
# 1  Argentina         ARG  01/01/2018       Coal            0.26
# 2  Argentina         ARG  01/01/2018        Gas            7.79
# 3  Argentina         ARG  01/01/2018      Hydro            3.69
# 4  Argentina         ARG  01/01/2018    Nuclear            0.64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12227 entries, 0 to 12226
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   entity          12227 non-null  object
#  1   entity code     12227 non-null  object
#  2   date            12227 non-null  object
#  3   series          12227 non-null  object
#  4   generation_TWh  12227 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 477.7+ KB

# %%
data.to_csv(r'C:\Users\ADMIN\Downloads\MODEL_TFT\data\raw\ember_data\all_country_data_cleaned.csv', index=False)
