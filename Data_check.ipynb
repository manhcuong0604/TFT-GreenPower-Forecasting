# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"data\processed\VN_data\full_vietnam_monthly.csv")
print(df.shape)
print(df.head(5))
# Out:
# (504, 16)
#      entity        date        series  is_aggregate_series  generation_twh  \
# 0  Viet Nam  2019-01-01          Coal                False            9.63
# 1  Viet Nam  2019-01-01           Gas                False            4.12
# 2  Viet Nam  2019-01-01         Hydro                False            3.39
# 3  Viet Nam  2019-01-01  Other fossil                False            0.00
# 4  Viet Nam  2019-01-01         Solar                False            0.00
#
#    IPI_Value  CPI_Value  GDP_VND_Trillion  Oil_Price  Oil_Change_Percent  \
# 0     134.05      100.1            7700.0      60.84               12.62
# 1     134.05      100.1            7700.0      60.84               12.62
# 2     134.05      100.1            7700.0      60.84               12.62
# 3     134.05      100.1            7700.0      60.84               12.62
# 4     134.05      100.1            7700.0      60.84               12.62
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   entity                             504 non-null    object
#  1   date                               504 non-null    object
#  2   series                             504 non-null    object
#  3   is_aggregate_series                504 non-null    bool
#  4   generation_twh                     504 non-null    float64
#  5   IPI_Value                          504 non-null    float64
#  6   CPI_Value                          504 non-null    float64
#  7   GDP_VND_Trillion                   504 non-null    float64
#  8   Oil_Price                          504 non-null    float64
#  9   Oil_Change_Percent                 504 non-null    float64
#  10  FDI_Disbursed_Monthly(bilionUSD)   504 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# entity                                 0
# date                                   0
# series                                 0
# is_aggregate_series                    0
# generation_twh                         0
# IPI_Value                              0
# CPI_Value                              0
# GDP_VND_Trillion                       0
# Oil_Price                              0
# Oil_Change_Percent                     0
# FDI_Disbursed_Monthly(bilionUSD)       0
# FDI_Registered_Monthly(bilionUSD)      0
# gas_price                            413
# gas_vol                              413
# castlecoal_price                       0
# castlecoal_vol                         0
# dtype: int64
